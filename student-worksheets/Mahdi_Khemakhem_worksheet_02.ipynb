# %% [markdown]
# # Worksheet 02
#
# Name: Mahdi Khemakhem
# UID: U18251472
#
# ### Topics
#
# - Effective Programming
#
# ### Effective Programming
#
# a) What is a drawback of the top down approach?

# %% [markdown]
# Runnable code will only be available in the end as you are assuming the helper functions are implemented and that they have their own helper functions that are also implemented.

# %% [markdown]
# b) What is a drawback of the bottom up approach?

# %% [markdown]
# You would need to know everything about the process up-front. Big overhead, hard to know exactly what you need, and could lead to writing extra functions.

# %% [markdown]
# c) What are 3 things you can do to have a better debugging experience?

# %% [markdown]
# print statements
# Reading the errors carefully
# Tracing code by hand
# Resting if there are marginal benefits to further coding

# %% [markdown]
# d) Follow along with the live coding. You can write your code here:

# %%
class Board:
    def __init__(self):
        self.board = [["_" for _ in range(8)] for _ in range(8)]
        self.solutions = int()


    def __repr__(self) -> str:
        res = ""
        for row in self.board:
            for col in row:
                res += col + " "
            res += "\n"
        return res

    def is_row_legal(self, row):
        for j in range(len(self.board[row])):
            if self.board[row][j] == "Q":
                return False
        return True
    
    def is_col_legal(self, col):
        for i in range(len(self.board)):
            if self.board[i][col] == "Q":
                return False
        return True

    def is_diagonal_legal(self, row, col):
        for i in range(len(self.board)):
            for j in range(len(self.board[i])):
                if self.board[i][j] == "Q":
                    if abs(row - i) == abs(col - j):
                        return False
        return True

    def is_legal(self, row, col):
        if not self.is_row_legal(row):
            return False
        if not self.is_col_legal(col):
            return False
        # check diagonals
        if not self.is_diagonal_legal(row, col):
            return False
        # if not self.prof_is_legal_diag(row, col):
        #     return False
        return True

    def set_queen_at(self, row, col):
        self.board[row][col] = "Q"
    
    def unset_queen_at(self, row):
        self.board[row] = ["_" for _ in range(8)]

    def is_on_board(self, row, col):
        return row >= 0 and row < 8 and col >= 0 and col < 8

    def prof_is_legal_diag(self, row, col):
        for i in range(len(self.board)):
            if self.is_on_board(row-1, col-1) and self.board[row-1][col-1] == "Q":
                return False
            if self.is_on_board(row-1, col+1) and self.board[row-1][col+1] == "Q":
                return False
            if self.is_on_board(row+1, col-1) and self.board[row+1][col-1] == "Q":
                return False
            if self.is_on_board(row+1, col+1) and self.board[row+1][col+1] == "Q":
                return False
        return True

    def get_queen_on(self, row):
        for col in range(len(self.board[row])):
            if self.board[row][col] == "Q":
                return col
        raise ValueError("No queen on row {}, likely programmer error.".format(row))

    def search(self):
        row = 0
        col = 0
        self.solutions = 0
        while row >= 0:
            if row < 8:
                if self.is_legal(row, col):
                    self.set_queen_at(row, col)
                    row += 1
                    col = 0
                else:
                    col += 1
                    while col >= 8:
                        if row == 0:
                            return                        
                        col = self.get_queen_on(row-1)
                        self.unset_queen_at(row-1)
                        col += 1
                        row -= 1


            else:
                print("found solution")
                print(self)
                self.solutions += 1
                col = self.get_queen_on(row-1)
                self.unset_queen_at(row-1)
                col += 1
                row -= 1
                if row == 0:
                    return
                elif col >= 8:
                    col = self.get_queen_on(row-1)
                    self.unset_queen_at(row-1)
                    col += 1
                    row -= 1
                    if row == 0:
                        return

                

my_board = Board()
my_board.search()
print(my_board.solutions)
# Out:
# found solution
# Q _ _ _ _ _ _ _
# _ _ _ _ Q _ _ _
# _ _ _ _ _ _ _ Q
# _ _ _ _ _ Q _ _
# _ _ Q _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ Q _ _ _ _ _ _
# _ _ _ Q _ _ _ _
#
# found solution
# Q _ _ _ _ _ _ _
# _ _ _ _ _ Q _ _
# _ _ _ _ _ _ _ Q
# _ _ Q _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ _ _ Q _ _ _ _
# _ Q _ _ _ _ _ _
# _ _ _ _ Q _ _ _
#
# found solution
# Q _ _ _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ _ _ Q _ _ _ _
# _ _ _ _ _ Q _ _
# _ _ _ _ _ _ _ Q
# _ Q _ _ _ _ _ _
# _ _ _ _ Q _ _ _
# _ _ Q _ _ _ _ _
#
# found solution
# Q _ _ _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ _ _ _ Q _ _ _
# _ _ _ _ _ _ _ Q
# _ Q _ _ _ _ _ _
# _ _ _ Q _ _ _ _
# _ _ _ _ _ Q _ _
# _ _ Q _ _ _ _ _
#
# found solution
# _ Q _ _ _ _ _ _
# _ _ _ Q _ _ _ _
# _ _ _ _ _ Q _ _
# _ _ _ _ _ _ _ Q
# _ _ Q _ _ _ _ _
# Q _ _ _ _ _ _ _
# _ _ _ _ _ _ Q _
# _ _ _ _ Q _ _ _
#
# found solution
# _ Q _ _ _ _ _ _
# _ _ _ _ Q _ _ _
# _ _ _ _ _ _ Q _
# Q _ _ _ _ _ _ _
# _ _ Q _ _ _ _ _
# _ _ _ _ _ _ _ Q
# _ _ _ _ _ Q _ _
# _ _ _ Q _ _ _ _
#
# found solution
# ...
